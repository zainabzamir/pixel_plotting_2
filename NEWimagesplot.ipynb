# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Open an image file
img = Image.open(r'deg_60\\image2.tiff')

# Convert the image to a NumPy array
img_array = np.array(img)

print(img_array.shape)  # Prints the dimensions of the image array
# Out:
# (960, 1280)

# %%
img.show()

# %%
display(img)
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=I;16B size=1280x960>

# %%
plt.plot(img_array[400,:])

# %%
np.sum(np.sum(img_array))
# Out:
# 2965900128

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Open an image file
img = Image.open(r'deg_60\\image3.tiff')

# Convert the image to a NumPy array
img_array = np.array(img)

print(img_array.shape)  # Prints the dimensions of the image array
# Out:
# (960, 1280)

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Open an image file
img = Image.open(r'deg_110\\image3.tiff')

# Convert the image to a NumPy array
img_array = np.array(img)

print(img_array.shape)  # Prints the dimensions of the image array
# Out:
# (960, 1280)

# %%
plt.plot(img_array[400,:])

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Open an image file
img = Image.open(r'deg_105\\image3.tiff')

# Convert the image to a NumPy array
img_array = np.array(img)

print(img_array.shape)  # Prints the dimensions of the image array
# Out:
# (960, 1280)

# %%
img.show()

# %%
display(img)
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=I;16B size=1280x960>

# %%
plt.plot(img_array[500,:])

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Open an image file
img = Image.open(r'deg_70\\image1.tiff')

# Convert the image to a NumPy array
img_array = np.array(img)

print(img_array.shape)  # Prints the dimensions of the image array
# Out:
# (960, 1280)

# %%
plt.plot(img_array[500,:])
